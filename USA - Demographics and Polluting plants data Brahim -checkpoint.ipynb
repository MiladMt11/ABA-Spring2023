# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ## Demographics and mortality

# %%
## more detailed dataset of demographics 2010-2019
demogr2=pd.read_csv('cc-est2019-alldata.csv',encoding='latin-1')
#demogr2=pd.read_csv('cc-est2019-alldata.csv', sep='|', names=m_cols , encoding='latin-1')
demogr2
# Out:
#         SUMLEV  STATE  COUNTY   STNAME         CTYNAME  YEAR  AGEGRP  TOT_POP  \
# 0           50      1       1  Alabama  Autauga County     1       0    54571
# 1           50      1       1  Alabama  Autauga County     1       1     3579
# 2           50      1       1  Alabama  Autauga County     1       2     3991
# 3           50      1       1  Alabama  Autauga County     1       3     4290
# 4           50      1       1  Alabama  Autauga County     1       4     4290
# ...        ...    ...     ...      ...             ...   ...     ...      ...
# 716370      50     56      45  Wyoming   Weston County    12      14      499
# 716371      50     56      45  Wyoming   Weston County    12      15      352
# 716372      50     56      45  Wyoming   Weston County    12      16      229
# 716373      50     56      45  Wyoming   Weston County    12      17      198
# 716374      50     56      45  Wyoming   Weston County    12      18      200
#
# ...

# %%
mortalityus = pd.read_csv("mort.csv")
#https://www.kaggle.com/datasets/IHME/us-countylevel-mortality?select=mort.csv

# %%
mortalityus
# Out:
#                          Location     FIPS  \
# 0                   United States      NaN
# 1                         Alabama      1.0
# 2         Autauga County, Alabama   1001.0
# 3         Baldwin County, Alabama   1003.0
# 4         Barbour County, Alabama   1005.0
# ...                           ...      ...
# 67069  Sweetwater County, Wyoming  56037.0
# 67070       Teton County, Wyoming  56039.0
# 67071       Uinta County, Wyoming  56041.0
# 67072    Washakie County, Wyoming  56043.0
# 67073      Weston County, Wyoming  56045.0
#
#                                       Category  Mortality Rate, 1980*  \
# 0                           Neonatal disorders                   9.18
# 1                           Neonatal disorders                  11.03
# 2                           Neonatal disorders                   9.58
# 3                           Neonatal disorders                   8.75
# 4                           Neonatal disorders                  12.30
# ...

# %%
demographicsusa=pd.read_csv('acs2015_census_tract_data.csv')
demographicsusa
#https://www.kaggle.com/datasets/muonneutrino/us-census-demographic-data
#2015
# Out:
#        CensusTract        State   County  TotalPop   Men  Women  Hispanic  \
# 0       1001020100      Alabama  Autauga      1948   940   1008       0.9
# 1       1001020200      Alabama  Autauga      2156  1059   1097       0.8
# 2       1001020300      Alabama  Autauga      2968  1364   1604       0.0
# 3       1001020400      Alabama  Autauga      4423  2172   2251      10.5
# 4       1001020500      Alabama  Autauga     10763  4922   5841       0.7
# ...            ...          ...      ...       ...   ...    ...       ...
# 73996  72153750501  Puerto Rico    Yauco      6205  3291   2914      99.7
# 73997  72153750502  Puerto Rico    Yauco      2122   921   1201      99.2
# 73998  72153750503  Puerto Rico    Yauco      2277  1097   1180      99.5
# 73999  72153750601  Puerto Rico    Yauco      5267  2663   2604      98.8
# 74000  72153750602  Puerto Rico    Yauco      2741  1181   1560      99.3
#
#        White  Black  Native  ...  Walk  OtherTransp  WorkAtHome  MeanCommute  \
# ...

# %%
demographicsusa.columns
# Out:
# Index(['CensusTract', 'State', 'County', 'TotalPop', 'Men', 'Women',
#        'Hispanic', 'White', 'Black', 'Native', 'Asian', 'Pacific', 'Citizen',
#        'Income', 'IncomeErr', 'IncomePerCap', 'IncomePerCapErr', 'Poverty',
#        'ChildPoverty', 'Professional', 'Service', 'Office', 'Construction',
#        'Production', 'Drive', 'Carpool', 'Transit', 'Walk', 'OtherTransp',
#        'WorkAtHome', 'MeanCommute', 'Employed', 'PrivateWork', 'PublicWork',
#        'SelfEmployed', 'FamilyWork', 'Unemployment'],
#       dtype='object')

# %%
demographicsusa.loc[demographicsusa['County'] == 'Autauga', 'TotalPop'].sum()
#antagua county pop is 55k, the different rows are the cities inside it
# Out:
# 55221

# %% [markdown]
# ## Pollution and manufac. Plants pollution

# %%
manpol=pd.read_excel('emissions_by_unit_and_fuel_type_c_d_aa_10_2022.xlsx')
#the last 4 columns are important
#https://www.epa.gov/ghgreporting/data-sets

# %%
manpol
# Out:
#         Facility Id        FRS Id                     Facility Name  \
# 0           1012147           NaN  17Z Gas Plant - Chevron USA Inc.
# 1           1012147           NaN  17Z Gas Plant - Chevron USA Inc.
# 2           1012147           NaN  17Z Gas Plant - Chevron USA Inc.
# 3           1012147           NaN  17Z Gas Plant - Chevron USA Inc.
# 4           1012147           NaN  17Z Gas Plant - Chevron USA Inc.
# ...             ...           ...                               ...
# 229848      1003318  1.100438e+11            ZYBACH CRYOGENIC PLANT
# 229849      1003318  1.100438e+11            ZYBACH CRYOGENIC PLANT
# 229850      1003318  1.100438e+11            ZYBACH CRYOGENIC PLANT
# 229851      1003318  1.100438e+11            ZYBACH CRYOGENIC PLANT
# 229852      1003318  1.100438e+11            ZYBACH CRYOGENIC PLANT
#
#               City State  Primary NAICS Code  Reporting Year  \
# 0       McKittrick    CA              211130            2018
# ...

# %%
pol=pd.read_csv("pollution_us_2000_2016.csv")
pol
#https://www.kaggle.com/datasets/sogun3/uspollution
# four major pollutants (Nitrogen Dioxide, Sulphur Dioxide, Carbon Monoxide and Ozone) for every day from 2000 - 2016
# Out:
#          Unnamed: 0  State Code  County Code  Site Num  \
# 0                 0           4           13      3002
# 1                 1           4           13      3002
# 2                 2           4           13      3002
# 3                 3           4           13      3002
# 4                 4           4           13      3002
# ...             ...         ...          ...       ...
# 1746656       24599          56           21       100
# 1746657       24600          56           21       100
# 1746658       24601          56           21       100
# 1746659       24602          56           21       100
# 1746660       24603          56           21       100
#
#                                          Address    State    County  \
# 0        1645 E ROOSEVELT ST-CENTRAL PHOENIX STN  Arizona  Maricopa
# 1        1645 E ROOSEVELT ST-CENTRAL PHOENIX STN  Arizona  Maricopa
# 2        1645 E ROOSEVELT ST-CENTRAL PHOENIX STN  Arizona  Maricopa
# ...
