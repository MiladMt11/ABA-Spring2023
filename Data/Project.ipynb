# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # Chronic Disease Indicators Dataset

# %%
CDI_df = pd.read_csv('U.S._Chronic_Disease_Indicators__CDI.csv')
# Out:
# C:\Users\Nima\AppData\Local\Temp/ipykernel_8820/127949515.py:1: DtypeWarning: Columns (10) have mixed types. Specify dtype option on import or set low_memory=False.
#   CDI_df = pd.read_csv('U.S._Chronic_Disease_Indicators__CDI.csv')

# %%
CDI_df.describe()
# Out:
#           YearStart       YearEnd  Response  DataValueAlt  LowConfidenceLimit  \
# count  1.185676e+06  1.185676e+06       0.0  8.045780e+05       682380.000000
# mean   2.015103e+03  2.015643e+03       NaN  1.005325e+03           50.264623
# std    3.320259e+00  3.001197e+00       NaN  1.880433e+04           89.004848
# min    2.001000e+03  2.001000e+03       NaN  0.000000e+00            0.000000
# 25%    2.013000e+03  2.013000e+03       NaN  1.610000e+01           11.000000
# 50%    2.015000e+03  2.016000e+03       NaN  4.000000e+01           28.500000
# 75%    2.018000e+03  2.018000e+03       NaN  7.600000e+01           56.300000
# max    2.021000e+03  2.021000e+03       NaN  2.925456e+06         2541.600000
#
#        HighConfidenceLimit  StratificationCategory2  Stratification2  \
# count        682380.000000                      0.0              0.0
# mean             61.873881                      NaN              NaN
# ...

# %% [markdown]
# ### Different Diseases

# %%
CDI_df.groupby(['Topic']).size().reset_index().rename(columns={0:'count'})
# Out:
#                                               Topic   count
# 0                                           Alcohol   66091
# 1                                         Arthritis   78300
# 2                                            Asthma   80342
# 3                                            Cancer  176339
# 4                            Cardiovascular Disease  157750
# 5                            Chronic Kidney Disease   24731
# 6             Chronic Obstructive Pulmonary Disease  152874
# 7                                          Diabetes  156808
# 8                                        Disability    3922
# 9                                      Immunization    9570
# 10                                    Mental Health   13200
# 11  Nutrition, Physical Activity, and Weight Status   75418
# 12                                     Older Adults   26316
# 13                                      Oral Health   22273
# 14                           Overarching Conditions   73260
# ...

# %%
CDI_df.groupby(['Topic','Question']).size().reset_index().rename(columns={0:'count'})
# Out:
#        Topic                                           Question  count
# 0    Alcohol                            Alcohol use among youth   1760
# 1    Alcohol                       Alcohol use before pregnancy   2783
# 2    Alcohol  Amount of alcohol excise tax by beverage type ...    324
# 3    Alcohol  Amount of alcohol excise tax by beverage type ...    324
# 4    Alcohol  Amount of alcohol excise tax by beverage type ...    324
# ..       ...                                                ...    ...
# 198  Tobacco  Quit attempts in the past year among current s...   9570
# 199  Tobacco                            Sale of cigarette packs    330
# 200  Tobacco  Secondary schools that have a comprehensive to...    208
# 201  Tobacco  States that allow stronger local tobacco contr...    486
# 202  Tobacco  States with strong polices that require retail...    487
#
# [203 rows x 3 columns]

# %% [markdown]
# ## Year

# %%
CDI_df[CDI_df['YearStart'] != CDI_df['YearEnd'] ]
# Out:
#         YearStart  YearEnd LocationAbbr LocationDesc         DataSource  \
# 29           2008     2012           NY     New York  Death Certificate
# 30           2009     2013           NY     New York  Death Certificate
# 31           2011     2015           NY     New York  Death Certificate
# 32           2012     2016           NY     New York  Death Certificate
# 33           2012     2016           CO     Colorado  Death Certificate
# ...           ...      ...          ...          ...                ...
# 503868       2019     2020           DE     Delaware               NSCH
# 503883       2019     2020           LA    Louisiana               NSCH
# 503885       2017     2018           WI    Wisconsin               NSCH
# 503886       2016     2017           NY     New York               NSCH
# 503894       2017     2018           IL     Illinois               NSCH
#
#               Topic                                           Question  \
# ...

# %% [markdown]
# There are some rows which their data is from for instance 2008 until 2012. So we need to have an average for these rows

# %%
print('Number of records with YearStart = YearEnd:',len(CDI_df[CDI_df['YearStart'] == CDI_df['YearEnd'] ].index))
# Out:
# Number of records with YearStart = YearEnd: 1024392

# %%
print('Number of records with YearStart != YearEnd:',len(CDI_df[CDI_df['YearStart'] != CDI_df['YearEnd'] ].index))
# Out:
# Number of records with YearStart != YearEnd: 161284

# %%
print('Min Year:',np.min(CDI_df['YearStart']),',',np.min(CDI_df['YearEnd']))
print('Max Year:',np.max(CDI_df['YearStart']),',',np.max(CDI_df['YearEnd']))
# Out:
# Min Year: 2001 , 2001
# Max Year: 2021 , 2021

# %% [markdown]
# ## States

# %% [markdown]
# Seems we are fine. But we must take into consideration that some rows don't have any value for the column "DataValue"

# %%
CDI_df.groupby(['LocationDesc']).size().reset_index().rename(columns={0:'count'})
# Out:
#             LocationDesc  count
# 0                Alabama  22058
# 1                 Alaska  22157
# 2                Arizona  22271
# 3               Arkansas  22384
# 4             California  22037
# 5               Colorado  22417
# 6            Connecticut  22082
# 7               Delaware  22151
# 8   District of Columbia  21936
# 9                Florida  22311
# 10               Georgia  21980
# 11                  Guam  14009
# 12                Hawaii  22420
# 13                 Idaho  21842
# 14              Illinois  22157
# 15               Indiana  21872
# 16                  Iowa  22510
# 17                Kansas  21988
# 18              Kentucky  22375
# 19             Louisiana  22053
# 20                 Maine  22142
# 21              Maryland  22346
# 22         Massachusetts  22349
# 23              Michigan  22422
# 24             Minnesota  22023
# 25           Mississippi  22100
# 26              Missouri  22163
# 27               Montana  21973
# ...

# %% [markdown]
# ## Issues

# %% [markdown]
# - Is 'DataValue' the number of people with the certain disease?
# - How about 'Stratification'? If it is 'Male', does it mean that the rows are just for males?
